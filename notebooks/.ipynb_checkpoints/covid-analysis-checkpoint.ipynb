# %%
# Import all the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the datasets into pandas dataframes
covid_df = pd.read_csv('../data/covidtesting.csv', engine='python')
vaccine_df = pd.read_csv('../data/vaccine_doses.csv', engine='python')
# Display what the raw data looks like
covid_df.head()
# Out:
#   Reported Date  Confirmed Negative  Presumptive Negative  \
# 0    2020-01-26                 NaN                   NaN
# 1    2020-01-27                 NaN                   NaN
# 2    2020-01-28                 NaN                   NaN
# 3    2020-01-30                 NaN                   NaN
# 4    2020-01-31                 NaN                   NaN
#
#    Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 0                   1.0                 NaN       NaN     NaN          NaN
# 1                   2.0                 NaN       NaN     NaN          NaN
# 2                   1.0                 1.0       NaN     NaN          1.0
# 3                   0.0                 2.0       NaN     NaN          2.0
# 4                   0.0                 2.0       NaN     NaN          2.0
#
#    Total patients approved for testing as of Reporting Date  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total tests completed in the last day  ...  \
# 0                                    NaN  ...
# 1                                    NaN  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
#
#    Number of patients in ICU on a ventilator due to COVID-19  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Num. of patients in ICU on a ventilator testing positive  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Num. of patients in ICU on a ventilator testing negative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total Positive LTC Resident Cases  Total Positive LTC HCW Cases  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Total LTC Resident Deaths  Total LTC HCW Deaths  Total_Lineage_B.1.1.7  \
# 0                        NaN                   NaN                    NaN
# 1                        NaN                   NaN                    NaN
# 2                        NaN                   NaN                    NaN
# 3                        NaN                   NaN                    NaN
# 4                        NaN                   NaN                    NaN
#
#    Total_Lineage_B.1.351  Total_Lineage_P.1
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN
#
# [5 rows x 26 columns]

# %%
# Display what the raw data looks like
vaccine_df.head()
# Out:
#   report_date previous_day_doses_administered total_doses_administered  \
# 0  2020-12-24                             NaN                   10,756
# 1  2020-12-30                           4,595                   18,603
# 2  2020-12-31                           5,463                   23,502
# 3  2021-01-01                           5,415                   28,887
# 4  2021-01-02                           4,305                   33,191
#
#   total_doses_in_fully_vaccinated_individuals   \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   total_individuals_fully_vaccinated
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN

# %%
# Rename the covid vaccines columns to match the formatting of other columns
# Also rename the 'report_date' column to be consistent with the other dataframe(s)
vaccine_df = vaccine_df.rename({'previous_day_doses_administered': 'Previous Day Doses Administered', 'report_date': 'Reported Date'}, axis='columns')

# %%
# Merge the datasets using 'report_date' as the unique identifier
merged_df = pd.merge(left=covid_df, right=vaccine_df, left_on='Reported Date', right_on='Reported Date')
# Display the new merged dataframe
merged_df.head()
# Out:
#   Reported Date  Confirmed Negative  Presumptive Negative  \
# 0    2020-12-24                 NaN                   NaN
# 1    2020-12-30                 NaN                   NaN
# 2    2020-12-31                 NaN                   NaN
# 3    2021-01-01                 NaN                   NaN
# 4    2021-01-02                 NaN                   NaN
#
#    Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 0                   NaN             19809.0  141023.0  4278.0     165110.0
# 1                   NaN             20558.0  153799.0  4474.0     178831.0
# 2                   NaN             21617.0  156012.0  4530.0     182159.0
# 3                   NaN             21582.0  158472.0  4581.0     184635.0
# 4                   NaN             22847.0  160526.0  4625.0     187998.0
#
#    Total patients approved for testing as of Reporting Date  \
# 0                                          7592554.0
# 1                                          7858200.0
# 2                                          7922058.0
# 3                                          7991628.0
# 4                                          8053029.0
#
#    Total tests completed in the last day  ...  Total Positive LTC HCW Cases  \
# 0                                64592.0  ...                        4068.0
# 1                                39210.0  ...                        4256.0
# 2                                63858.0  ...                        4280.0
# 3                                70570.0  ...                        4329.0
# 4                                61401.0  ...                        4365.0
#
#    Total LTC Resident Deaths  Total LTC HCW Deaths  Total_Lineage_B.1.1.7  \
# 0                     2643.0                   8.0                    NaN
# 1                     2738.0                   8.0                    NaN
# 2                     2777.0                   8.0                    NaN
# 3                     2800.0                   8.0                    NaN
# 4                     2814.0                   8.0                    NaN
#
#    Total_Lineage_B.1.351  Total_Lineage_P.1  Previous Day Doses Administered  \
# 0                    NaN                NaN                              NaN
# 1                    NaN                NaN                            4,595
# 2                    NaN                NaN                            5,463
# 3                    NaN                NaN                            5,415
# 4                    NaN                NaN                            4,305
#
#    total_doses_administered  total_doses_in_fully_vaccinated_individuals   \
# 0                    10,756                                           NaN
# 1                    18,603                                           NaN
# 2                    23,502                                           NaN
# 3                    28,887                                           NaN
# 4                    33,191                                           NaN
#
#    total_individuals_fully_vaccinated
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 30 columns]

# %%
# Remove the first two rows since we want to get rid of the 2020 rows
merged_df = merged_df.iloc[2:]

# %%
# Shift Column 'Previous Day Doses Administered' up by one to make the data correspond to that same day
merged_df['Previous Day Doses Administered'] = merged_df['Previous Day Doses Administered'].shift(-1)

# Rename Column to reflect the above changes
merged_df = merged_df.rename({'Previous Day Doses Administered': 'Doses Administered'}, axis='columns')
merged_df.head()
# Out:
#   Reported Date  Confirmed Negative  Presumptive Negative  \
# 2    2020-12-31                 NaN                   NaN
# 3    2021-01-01                 NaN                   NaN
# 4    2021-01-02                 NaN                   NaN
# 5    2021-01-03                 NaN                   NaN
# 6    2021-01-04                 NaN                   NaN
#
#    Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 2                   NaN             21617.0  156012.0  4530.0     182159.0
# 3                   NaN             21582.0  158472.0  4581.0     184635.0
# 4                   NaN             22847.0  160526.0  4625.0     187998.0
# 5                   NaN             23611.0  162701.0  4650.0     190962.0
# 6                   NaN             24778.0  164775.0  4679.0     194232.0
#
#    Total patients approved for testing as of Reporting Date  \
# 2                                          7922058.0
# 3                                          7991628.0
# 4                                          8053029.0
# 5                                          8103832.0
# 6                                          8142953.0
#
#    Total tests completed in the last day  ...  Total Positive LTC HCW Cases  \
# 2                                63858.0  ...                        4280.0
# 3                                70570.0  ...                        4329.0
# 4                                61401.0  ...                        4365.0
# 5                                49803.0  ...                        4397.0
# 6                                39121.0  ...                        4434.0
#
#    Total LTC Resident Deaths  Total LTC HCW Deaths  Total_Lineage_B.1.1.7  \
# 2                     2777.0                   8.0                    NaN
# 3                     2800.0                   8.0                    NaN
# 4                     2814.0                   8.0                    NaN
# 5                     2829.0                   8.0                    NaN
# 6                     2843.0                   8.0                    NaN
#
#    Total_Lineage_B.1.351  Total_Lineage_P.1  Doses Administered  \
# 2                    NaN                NaN               5,415
# 3                    NaN                NaN               4,305
# 4                    NaN                NaN               4,361
# 5                    NaN                NaN               4,808
# 6                    NaN                NaN               7,607
#
#    total_doses_administered  total_doses_in_fully_vaccinated_individuals   \
# 2                    23,502                                           NaN
# 3                    28,887                                           NaN
# 4                    33,191                                           NaN
# 5                    37,551                                           NaN
# 6                    42,419                                           NaN
#
#    total_individuals_fully_vaccinated
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
#
# [5 rows x 30 columns]

# %%
# We need two more columns for New Deaths and New Cases since the data for that is currently a cumilitive total
new_cases = []
new_deaths = []

# Calculate daily change by getting the difference of one day from the previous day (for deaths and cases)
# Loop through all rows and do the above^
for i in range(2, len(merged_df.index)+2):
    if i < 98:
        new_cases.append(merged_df['Total Cases'][i+1] - merged_df['Total Cases'][i])
        new_deaths.append(merged_df['Deaths'][i+1] - merged_df['Deaths'][i])       

# Remove the first entry (December 31st, 2020) since it is used simply to get the values for January 1st, 2021
merged_df = merged_df.iloc[1:]

# Add the two new columns of data to the merged dataframe
merged_df['New Cases'] = new_cases
merged_df['New Deaths'] = new_deaths

#Remove the cumilitive total columns
merged_df = 
merged_df
# Out:
#    Reported Date  Confirmed Negative  Presumptive Negative  \
# 3     2021-01-01                 NaN                   NaN
# 4     2021-01-02                 NaN                   NaN
# 5     2021-01-03                 NaN                   NaN
# 6     2021-01-04                 NaN                   NaN
# 7     2021-01-05                 NaN                   NaN
# ..           ...                 ...                   ...
# 94    2021-04-02                 NaN                   NaN
# 95    2021-04-03                 NaN                   NaN
# 96    2021-04-04                 NaN                   NaN
# 97    2021-04-05                 NaN                   NaN
# 98    2021-04-06                 NaN                   NaN
#
#     Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 3                    NaN             21582.0  158472.0  4581.0     184635.0
# 4                    NaN             22847.0  160526.0  4625.0     187998.0
# 5                    NaN             23611.0  162701.0  4650.0     190962.0
# 6                    NaN             24778.0  164775.0  4679.0     194232.0
# 7                    NaN             25840.0  166790.0  4730.0     197360.0
# ..                   ...                 ...       ...     ...          ...
# 94                   NaN             22016.0  326121.0  7412.0     355549.0
# 95                   NaN             23190.0  327940.0  7428.0     358558.0
# 96                   NaN             24320.0  329839.0  7440.0     361599.0
# 97                   NaN             25487.0  331600.0  7450.0     364537.0
# 98                   NaN             26568.0  333576.0  7458.0     367602.0
#
#     Total patients approved for testing as of Reporting Date  \
# 3                                           7991628.0
# 4                                           8053029.0
# 5                                           8103832.0
# 6                                           8142953.0
# 7                                           8178105.0
# ..                                                ...
# 94                                         12675796.0
# 95                                         12734913.0
# 96                                         12781293.0
# 97                                         12817856.0
# 98                                         12855397.0
#
#     Total tests completed in the last day  ...  Total LTC HCW Deaths  \
# 3                                 70570.0  ...                   8.0
# 4                                 61401.0  ...                   8.0
# 5                                 49803.0  ...                   8.0
# 6                                 39121.0  ...                   8.0
# 7                                 35152.0  ...                   8.0
# ..                                    ...  ...                   ...
# 94                                62333.0  ...                  10.0
# 95                                59117.0  ...                  10.0
# 96                                46380.0  ...                  10.0
# 97                                36563.0  ...                  10.0
# 98                                37541.0  ...                  10.0
#
#     Total_Lineage_B.1.1.7  Total_Lineage_B.1.351  Total_Lineage_P.1  \
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
# 5                     NaN                    NaN                NaN
# 6                     NaN                    NaN                NaN
# 7                     NaN                    NaN                NaN
# ..                    ...                    ...                ...
# 94                 2022.0                   70.0              103.0
# 95                 2042.0                   70.0              102.0
# 96                 2114.0                   71.0              103.0
# 97                 2135.0                   71.0              103.0
# 98                 2165.0                   71.0              106.0
#
#     Doses Administered  total_doses_administered  \
# 3                4,305                    28,887
# 4                4,361                    33,191
# 5                4,808                    37,551
# 6                7,607                    42,419
# 7               10,350                    50,030
# ..                 ...                       ...
# 94              59,567                 2,364,496
# 95              69,125                 2,424,063
# 96              52,452                 2,493,188
# 97              76,199                 2,545,640
# 98                 NaN                 2,621,839
#
#     total_doses_in_fully_vaccinated_individuals   \
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# ..                                           ...
# 94                                       640,700
# 95                                       642,937
# 96                                       644,095
# 97                                       644,393
# 98                                       646,295
#
#     total_individuals_fully_vaccinated  New Cases  New Deaths
# 3                                  NaN     2476.0        51.0
# 4                                  NaN     3363.0        44.0
# 5                                  NaN     2964.0        25.0
# 6                                  NaN     3270.0        29.0
# 7                                  NaN     3128.0        51.0
# ..                                 ...        ...         ...
# 94                             320,350     3089.0        23.0
# 95                             321,469     3009.0        16.0
# 96                             322,048     3041.0        12.0
# 97                             322,197     2938.0        10.0
# 98                             323,148     3065.0         8.0
#
# [96 rows x 32 columns]

# %%
# Reset the index to start at 1
merged_df.index -= 2
merged_df['id'] = merged_df.index

# Remove the last row since there's no vaccination data for April 6th
merged_df = merged_df.iloc[:-1]
merged_df
# Out:
#    Reported Date  Confirmed Negative  Presumptive Negative  \
# 1     2021-01-01                 NaN                   NaN
# 2     2021-01-02                 NaN                   NaN
# 3     2021-01-03                 NaN                   NaN
# 4     2021-01-04                 NaN                   NaN
# 5     2021-01-05                 NaN                   NaN
# ..           ...                 ...                   ...
# 91    2021-04-01                 NaN                   NaN
# 92    2021-04-02                 NaN                   NaN
# 93    2021-04-03                 NaN                   NaN
# 94    2021-04-04                 NaN                   NaN
# 95    2021-04-05                 NaN                   NaN
#
#     Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 1                    NaN             21582.0  158472.0  4581.0     184635.0
# 2                    NaN             22847.0  160526.0  4625.0     187998.0
# 3                    NaN             23611.0  162701.0  4650.0     190962.0
# 4                    NaN             24778.0  164775.0  4679.0     194232.0
# 5                    NaN             25840.0  166790.0  4730.0     197360.0
# ..                   ...                 ...       ...     ...          ...
# 91                   NaN             20875.0  324196.0  7389.0     352460.0
# 92                   NaN             22016.0  326121.0  7412.0     355549.0
# 93                   NaN             23190.0  327940.0  7428.0     358558.0
# 94                   NaN             24320.0  329839.0  7440.0     361599.0
# 95                   NaN             25487.0  331600.0  7450.0     364537.0
#
#     Total patients approved for testing as of Reporting Date  \
# 1                                           7991628.0
# 2                                           8053029.0
# 3                                           8103832.0
# 4                                           8142953.0
# 5                                           8178105.0
# ..                                                ...
# 91                                         12613463.0
# 92                                         12675796.0
# 93                                         12734913.0
# 94                                         12781293.0
# 95                                         12817856.0
#
#     Total tests completed in the last day  ...  Total_Lineage_B.1.1.7  \
# 1                                 70570.0  ...                    NaN
# 2                                 61401.0  ...                    NaN
# 3                                 49803.0  ...                    NaN
# 4                                 39121.0  ...                    NaN
# 5                                 35152.0  ...                    NaN
# ..                                    ...  ...                    ...
# 91                                62290.0  ...                 1953.0
# 92                                62333.0  ...                 2022.0
# 93                                59117.0  ...                 2042.0
# 94                                46380.0  ...                 2114.0
# 95                                36563.0  ...                 2135.0
#
#     Total_Lineage_B.1.351  Total_Lineage_P.1  Doses Administered  \
# 1                     NaN                NaN               4,305
# 2                     NaN                NaN               4,361
# 3                     NaN                NaN               4,808
# 4                     NaN                NaN               7,607
# 5                     NaN                NaN              10,350
# ..                    ...                ...                 ...
# 91                   67.0               96.0              88,183
# 92                   70.0              103.0              59,567
# 93                   70.0              102.0              69,125
# 94                   71.0              103.0              52,452
# 95                   71.0              103.0              76,199
#
#     total_doses_administered  total_doses_in_fully_vaccinated_individuals   \
# 1                     28,887                                           NaN
# 2                     33,191                                           NaN
# 3                     37,551                                           NaN
# 4                     42,419                                           NaN
# 5                     50,030                                           NaN
# ..                       ...                                           ...
# 91                 2,276,313                                       635,430
# 92                 2,364,496                                       640,700
# 93                 2,424,063                                       642,937
# 94                 2,493,188                                       644,095
# 95                 2,545,640                                       644,393
#
#     total_individuals_fully_vaccinated  New Cases  New Deaths  id
# 1                                  NaN     2476.0        51.0   1
# 2                                  NaN     3363.0        44.0   2
# 3                                  NaN     2964.0        25.0   3
# 4                                  NaN     3270.0        29.0   4
# 5                                  NaN     3128.0        51.0   5
# ..                                 ...        ...         ...  ..
# 91                             317,715     2557.0        23.0  91
# 92                             320,350     3089.0        23.0  92
# 93                             321,469     3009.0        16.0  93
# 94                             322,048     3041.0        12.0  94
# 95                             322,197     2938.0        10.0  95
#
# [95 rows x 33 columns]

# %%
new_cases_df = merged_df[['Doses Administered', 'New Cases']]

x = merged_df['Doses Administered']
y = merged_df['New Cases']

new_cases_df.plot.scatter(x='Doses Administered', y='New Cases')
# Out:
# <AxesSubplot:xlabel='Doses Administered', ylabel='New Cases'>

# %%
new_cases_df = merged_df[['Reported Date', 'New Cases']]

x = merged_df['id']
y = merged_df['New Cases']

new_cases_df.plot.scatter(x='Reported Date', y='New Cases')
# Out:
# <AxesSubplot:xlabel='Reported Date', ylabel='New Cases'>

# %%
#create scatterplot
plt.scatter(x, y)

# %%
#polynomial fit with degree = 2
model = np.poly1d(np.polyfit(x, y, 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(1, 100, 50)
plt.scatter(x, y)
plt.plot(polyline, model(polyline), "r")
plt.show()
print(model)
# Out:
#        2
# 1.044 x - 112.8 x + 4143

# %%
new_deaths_df = merged_df[['Reported Date', 'New Deaths']]

y = merged_df['New Cases']

new_deaths_df.plot.scatter(x='Reported Date', y='New Deaths')
# Out:
# <AxesSubplot:xlabel='Reported Date', ylabel='New Deaths'>

# %%
hospitalized_df = merged_df[['Reported Date', 'Number of patients hospitalized with COVID-19']]

y = merged_df['Number of patients hospitalized with COVID-19']

hospitalized_df.plot.scatter(x='Reported Date', y='Number of patients hospitalized with COVID-19')
# Out:
# <AxesSubplot:xlabel='Reported Date', ylabel='Number of patients hospitalized with COVID-19'>

# %%
doses_df = merged_df[['Reported Date', 'Doses Administered']]

y = merged_df['Doses Administered']

doses_df.plot.scatter(x='Reported Date', y='Doses Administered')
# Out:
# <AxesSubplot:xlabel='Reported Date', ylabel='Doses Administered'>
